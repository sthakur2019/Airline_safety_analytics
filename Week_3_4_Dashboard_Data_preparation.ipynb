# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/sohantha/Documents/Sohan Thakur/Personal/Bellevue University/DSC640/ProjectTask'

# %%
# !ls
# Out:
# Aviation_Data_Table_Raw.xlsx  auto-fatalities.xlsx
# Aviation_Data_Table_v1.xlsx   ~$Aviation_Data_Table_v1.xlsx
# Untitled.ipynb                ~$auto-fatalities.xlsx
# airline-safety.csv

# %%
aviation_data_path = "/Users/sohantha/Documents/Sohan Thakur/Personal/Bellevue University/DSC640/ProjectTask/"+"Aviation_Data_Table_v1.xlsx"

# %%
df_aviation_data = pd.read_excel(aviation_data_path)

# %%
df_aviation_data.head(100)
# Out:
#              US_CARRIER_CATEGORY  Year  All_Accidents  Fatal_accidents  \
# 0   Airlines (scheduled service)  1997             43                3
# 1   Airlines (scheduled service)  1998             41                1
# 2   Airlines (scheduled service)  1999             40                2
# 3   Airlines (scheduled service)  2000             49                2
# 4   Airlines (scheduled service)  2001             41                6
# ..                           ...   ...            ...              ...
# 95              General aviation  2000           1837              345
# 96              General aviation  2001           1728              326
# 97              General aviation  2002           1716              345
# 98              General aviation  2003           1741              352
# 99              General aviation  2004           1619              314
#
#     On_board_fatalities Total_flight_hours  Flight_miles  \
# ...

# %%
df_auto_fatalities = pd.read_excel("auto-fatalities.xlsx")

# %%
df_auto_fatalities.head(10)
# Out:
#    Year  Deaths  Crashes  Motor Vehicles  Miles_traveled_in_millions  \
# 0  1975   44525    39161           55534                     1330074
# 1  1976   45523    39747           56084                     1409163
# 2  1977   47878    42211           60516                     1476567
# 3  1978   50331    44433           64144                     1548213
# 4  1979   51093    45223           64762                     1529133
# 5  1980   51091    45284           63485                     1520857
# 6  1981   49301    44000           62699                     1550271
# 7  1982   43945    39092           56455                     1592481
# 8  1983   42589    37976           55106                     1649106
# 9  1984   44257    39631           57972                     1716768
#
#    Fatalities_Per_100_Million_VMT  Population  \
# 0                            3.35   215973199
# 1                            3.23   218035164
# 2                            3.24   220239425
# ...
